# %% [markdown]
# # Functions
# Functions are a vital part of coding. They provide a means of storing and naming a pieces of code that may be called repeatedly and in many different contexts. You've probably used a number of intrinsic functions already, even if you didn't appreciate what they were. In this notebook we'll examine the syntax for calling a function, look at some intrinsic functions as examples and then detail how to write your own functions.

# %% [markdown]
# ## Intrinsic Functions
#
# Intrinsic functions are functions that are built into Python and are available by default. For example, we've already used the ```print``` and ```type``` functions.
#
# There are many intrinsic functions in Python. Below is a (non-exhaustive) list of some intrinsic functions you may find useful.
#
# | Function |  Description |
# |------|-------|
# | ```abs(x)``` | Returns the absolute value of the numeric variable ```x``` |
# | ```all(x)``` | Returns True if all values of the collection ```x``` are True and False if not |
# | ```any(x)``` | Returns True if any value of the collection ```x``` are True and False if not |
# | ```float(x)``` | Returns a float version of the numeric variable ```x``` |
# | ```help(x)``` | Returns help information for the variable ```x``` |
# | ```input(x)``` | Prompts a user for an input with the string ```x``` and returns the entered value as a string |
# | ```len(x)``` | Returns the number of items in a collection ```x``` |
# | ```max(x)``` | Returns the maximum value in a collection ```x``` |
# | ```min(x)``` | Returns the minimum value in a collection ```x``` |
# | ```print(x)``` | Prints a representation of the variable ```x``` to the standard output of the device |
# | ```sum(x)``` | Returns the arithmetic sum of a collection ```x``` |
# | ```type(x)``` | Returns the type of the variable ```x``` |
#
# The function ```help``` can be particularly useful if you want a more detailed and precise description of a function.

# %%
help(abs)

# %% [markdown]
# When you create variables, or functions of your own, it is highly recommended to avoid names of intrinsic functions. This is because the variable would hide function. For example, if we create a variable called ```print```, we can no longer directly use the ```print``` function.

# %% [markdown]
# ## Defining Your Own Functions
# To define your own function, the basic syntax for a function which receives two arguments is:
#
# ```python
# def function_name(param1, param2):
#   [What the function does]
#   [May span multiple lines]
#   return x
#
# a = 1 # This line is not part of the function
# ```
#
# The ```def``` statement tells Python you are about to define a function. This is followed by the function name. Function names have the same restrictions as variable names. It's advisable to give your functions descriptive and unique names so you easily understand what your function does.
#
# Following the name of the function is a set of parameters. A parameter is a variable inside a function that is used to receive an argument passed to the function when it's called. A colon is used before the body of the function is included in an indented block. The definition of the function ends at the first line of code that is not indented.
#
# Function definition may end with a keyword ```return``` followed by a space, then an expression. In this case, the expression is evaluated and value returned. The function then ends.

# %%
# Lets define a function that adds two numbers and returns the result
def add_numbers(a, b):
    return a + b

# %% [markdown]
# ## Calling a function
#
# We can call this function in the same way as an intrinsic function. In its simplest form, one argument must be passed into each parameter. The first argument will be passed into the first parameter when the function is called, the second argument will be passed into the second parameter and so on.
#
# You must define a function above where it is used elsewhere in your code. Below is example of a definition of and call to a function that demonstrates some of these features:

# %%
x = 20
y = 5

a = add_numbers(x, y)
print(a)

# %% [markdown]
# If an execution of your function reaches the end of the indented block without a return statement being called, the value ```None``` will be returned instead. ```None``` will also be returned if a ```return``` statement is used without a following expression. When the execution of a function reaches a ```return``` statement, the execution of the function will end and the execution of the code will return to after the call of the function.

# %%
def function_with_no_return():
    print("This function does not return anything.")

print(function_with_no_return())

# %% [markdown]
# ## Variable scope
#
# Any variables defined within a function are defined only in the "scope" of that function (i.e. within the indented block) and will be discarded once the function has finished. This means they cannot be referenced outside the function. In addition, variables defined within the function will not conflict with variables defined outside the code block, even if they have identical names.
#
# In the example below, ```local_variable``` is defined in the function ```add_one```. If you try to access it in outside function, NameError is raised.

# %%
def add_one(number):
    local_variable = number + 1  
    return local_variable

print(add_one(5))  # This will print 6
print(local_variable)  # This will raise an error because local_variable is not defined in this scope

# %% [markdown]
# ## Exercise 1
#
# Write a function ```evaluate_linear_equation``` that uses linear equation $y = mx + c$ to calculate value of $y$ given value of $x$.
#
# Your function will have three arguments:
# - slope $m$
# - y-intercept $c$
# - value of $x$

# %%
# Write your function here



# Sample code that should print the value 11
print(evaluate_linear_equation(2, 3, 4))  

# Sample code that should print the value 19
print(evaluate_linear_equation(2, 3, 8))  

# Sample code that should print the value 3
print(evaluate_linear_equation(0, 3, 2))  

# Sample code that should print the value 10
print(evaluate_linear_equation(2, 0, 5))

# %% [markdown]
# ## Functions Calling Functions
# Functions may call other functions (providing the called function is defined before the definition of the calling function).
#
# For example, below is a set of functions that calculates area of circle, circumference of a circle, and area of a rectangle. These functions can be used together to calculate a surface area of a cylinder, given radius of the base and height.
#
# You will notice that ```cylinder_surface``` function calls ```circle_area``` and ```rectangle_area```. The function ```circle_circumference``` is called as a parameter for ```rectangle_area```.

# %%
def circle_area(radius):
    pi = 3.14159
    area = pi * radius ** 2
    return area

def circle_circumference(radius):
    pi = 3.14159
    circ = 2 * pi * radius
    return circ

def rectangle_area(length, width):
    area = length * width
    return area

def cylinder_surface(radius, height):
    surface_area =  2 * circle_area(radius) + rectangle_area(circle_circumference(radius), height)
    return surface_area



print(cylinder_surface(3, 5))  # This will print the surface area of a cylinder with radius 3 and height 5

# %% [markdown]
# Think about the example above. What would happen if one asked for a cylinder surface with negative paramenter by mistake?
#
# We have not learned enough to code the solution yet, but it is a good idea to start thinking critically about various "edge cases" right from the start.

# %% [markdown]
# ## Functions in general
#
# When building up a larger piece of code, it's often useful to break it into smaller functions which use each other. In these cases, it's good practice to start by writing small low-level functions that perform entirely self-contained tasks, test these independent functions and then build up larger functions that call these smaller functions. This splits up functionality into small functions which can then be reused in other contexts, as well as making the code easier to read, test, and debug.
#
# It is good practice to keep the length of each function in a project to be relatively short (a few dozen lines or less). It is a good idea to ask yourself if the function is doing just one thing. If it does more than that, you may want to split it.
#
# In the example above the goal was to write a piece of code calculates the area of a cylinder. You can think of it as area of a circle (times two) and area of a rectangle. Once you develop those two fuctions and test them, you can be confident that they work as expected, you can concentrate on writing new functions. This allowed us to compartmentalise the problem and focus on one small part at a time, reducing the complexity of the code we're working on at any given time.
#
# From now on, we will concentrate on what it means to test your function and how can one be reasonable confident that a function is doing what is expected. This is part of good sofware engineering practice.
