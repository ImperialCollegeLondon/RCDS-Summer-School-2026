# %% [markdown]
# # Task: Loops and Testing
#
# For each subtask, write a function that returns the string values given.
#
# Try to complete as much of this notebook as you can in the time available. It is OK if you don't complete everything.
#
# As you complete each task, paste the result and code into this form:
#
# https://form.menti.com/s/alkdwu9juhr6
#
# At the end of the allotted time, submit the form so we can see how far you got through the tasks. This is for the purposes of the educational study - remember that you are completely anonymous.
#
# If you finish early, use the extra time to make sure you understand all of the code you have produced.

# %% [markdown]
# ## 1. `line()`
#
# `line(1)` returns
# ```
# *
# ```
#
# `line(2)` returns
# ```
# **
# ```
#
# `line(5)` returns
# ```
# *****
# ```

# %%
# paste the output as your answer to part 1
print(line(10))

# %% [markdown]
# ## 2. `triangle()`
#
# `triangle(1)` returns
# ```
# *
# ```
#
# `triangle(2)` returns
# ```
# *
# **
# ```
#
# `triangle(3)` returns
# ```
# *
# **
# ***
# ```

# %%
# paste the output as your answer to part 2
print(triangle(10))

# %% [markdown]
# ## 3. `square()`
#
# `square(1)` returns
# ```
# *
# ```
# `square(2)` returns
# ```
# **
# **
# ```
# `square(3)` returns
# ```
# ***
# * *
# ***
# ```
# `square(4) returns
# ```
# ****
# *  *
# *  *
# ****
# ```

# %%
# paste the output as your answer to part 3
print(square(10))

# %% [markdown]
# ## 4. `mosaic()`
#
# `mosaic(1)` returns
# ```
# *
# ```
# `mosaic(2)` returns
# ```
# *.
# .*
# ```
# `mosaic(5)` returns
# ```
# *.*.*
# .*.*.
# *.*.*
# .*.*.
# *.*.*
# ```

# %%
# paste the output as your answer to part 4
print(mosaic(10))
